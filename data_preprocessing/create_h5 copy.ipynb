# %% [markdown]
# #P4J library must be compiled and installed
# #mexican hatt too
#
# -march=x86-64
# python setup.py build_ext --inplace
# pip install .

# %%
import glob
import pickle
from tqdm import tqdm
import pandas as pd
import h5py
import numpy as np
import glob
import os
import re

# %%
from pkl_h5 import PKL2H5
import logging
ASTRO_OBJ_INPUT_PATH = '/home/magdalena/pipeline/data_preprocessing/sixplusdets/2021_out/'
ASTRO_OBJ_INPUT_DIRS = glob.glob('./sixplusdets/*/')
print(ASTRO_OBJ_INPUT_DIRS) #sanity check!
CROSS_CONT_FILE = '/home/magdalena/pipeline/data_preprocessing/sixplusdets/partitions.parquet'
OUTPUT_DIR = './data/H5_FILES/'
# Out:
# ['./sixplusdets/2019_out/', './sixplusdets/2022_out/', './sixplusdets/2023_out/', './sixplusdets/2020_out/', './sixplusdets/2021_out/']

# %%
 
logger = logging.getLogger()
log_file_name = 'multiple_h5.log'
logging.basicConfig(filename=log_file_name,
                    encoding='utf-8',
                    level=logging.DEBUG,
                    filemode='w',  # This will overwrite the log file
                    format = "[%(asctime)s] [%(levelname)s]: %(message)s", datefmt="%H:%M:%S"
                    )

# %%
for year_dir in ASTRO_OBJ_INPUT_DIRS:
    match = re.search(r"/(\d{4})_", year_dir)
    year = match.group(1)
    output_dir = os.path.join(OUTPUT_DIR,str(year))
    output_dataset_name = 'clean_'+str(year)+'.h5'
    h5_creator = PKL2H5(year_dir,
                output_dir,
                CROSS_CONT_FILE,
                output_dataset_name,
                logger=logger,
                purge_output_directory=False
                )
    
    
    h5_creator.create_dataset(train_val_split=0.2,
                              k_folds=5,
                            generate_features_qt= True,
                            generate_metadata_qt=True)
# Out:
# Searching for .pkl files: 100%|██████████| 28812/28812 [00:06<00:00, 4706.27files/s]
#    - Getting flux data for all astro objects: 100%|██████████| 28812/28812 [00:06<00:00, 4494.93it/s]
#    - Getting mask data for all astro objects: 100%|██████████| 28812/28812 [00:06<00:00, 4754.55it/s]
#    - Getting time data for all astro objects: 100%|██████████| 28812/28812 [00:05<00:00, 4885.10it/s]
#    - Getting feature data for all astro objects: 100%|██████████| 28812/28812 [00:11<00:00, 2470.86it/s]
#    - Getting meta data for all astro objects: 100%|██████████| 28812/28812 [00:11<00:00, 2486.14it/s]
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Searching for .pkl files: 100%|██████████| 47938/47938 [00:09<00:00, 4801.12files/s]
#    - Getting flux data for all astro objects: 100%|██████████| 47938/47938 [00:09<00:00, 5198.65it/s]
#    - Getting mask data for all astro objects: 100%|██████████| 47938/47938 [00:09<00:00, 5293.62it/s]
#    - Getting time data for all astro objects: 100%|██████████| 47938/47938 [00:09<00:00, 5081.54it/s]
#    - Getting feature data for all astro objects: 100%|██████████| 47938/47938 [00:19<00:00, 2452.38it/s]
#    - Getting meta data for all astro objects: 100%|██████████| 47938/47938 [00:19<00:00, 2462.19it/s]
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Searching for .pkl files: 100%|██████████| 19514/19514 [00:03<00:00, 5200.23files/s]
#    - Getting flux data for all astro objects: 100%|██████████| 19514/19514 [00:03<00:00, 5326.47it/s]
#    - Getting mask data for all astro objects: 100%|██████████| 19514/19514 [00:03<00:00, 5311.85it/s]
#    - Getting time data for all astro objects: 100%|██████████| 19514/19514 [00:03<00:00, 5333.31it/s]
#    - Getting feature data for all astro objects: 100%|██████████| 19514/19514 [00:07<00:00, 2540.19it/s]
#    - Getting meta data for all astro objects: 100%|██████████| 19514/19514 [00:07<00:00, 2444.16it/s]
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Searching for .pkl files: 100%|██████████| 87690/87690 [00:16<00:00, 5473.86files/s]
#    - Getting flux data for all astro objects: 100%|██████████| 87690/87690 [00:16<00:00, 5259.66it/s]
#    - Getting mask data for all astro objects: 100%|██████████| 87690/87690 [00:16<00:00, 5302.66it/s]
#    - Getting time data for all astro objects: 100%|██████████| 87690/87690 [00:16<00:00, 5379.64it/s]
#    - Getting feature data for all astro objects: 100%|██████████| 87690/87690 [00:34<00:00, 2539.43it/s]
#    - Getting meta data for all astro objects: 100%|██████████| 87690/87690 [00:34<00:00, 2550.89it/s]
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Searching for .pkl files: 100%|██████████| 91377/91377 [00:17<00:00, 5276.31files/s]
#    - Getting flux data for all astro objects: 100%|██████████| 91377/91377 [00:17<00:00, 5300.63it/s]
#    - Getting mask data for all astro objects: 100%|██████████| 91377/91377 [00:17<00:00, 5361.15it/s]
#    - Getting time data for all astro objects: 100%|██████████| 91377/91377 [00:16<00:00, 5460.87it/s]
#    - Getting feature data for all astro objects: 100%|██████████| 91377/91377 [00:36<00:00, 2491.12it/s]
#    - Getting meta data for all astro objects: 100%|██████████| 91377/91377 [00:36<00:00, 2515.09it/s]
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/magdalena/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
