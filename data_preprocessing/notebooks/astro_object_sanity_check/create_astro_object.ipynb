# %%
# %cd /home/magdalena/pipeline

from data_preprocessing.src.h5_constructor.CreateAstroObjectPKL import CreateAstroObjectPKL 
to_pkl = CreateAstroObjectPKL(chunks_dir='/home/magdalena/pipeline/data_preprocessing/data/test',
                              output_dir='/home/magdalena/pipeline/data_preprocessing/data/test_pkl',
                              n_jobs=1)
# Out:
# /home/magdalena/pipeline
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 get_ipython().run_line_magic('cd', '/home/magdalena/pipeline')
#       3 from data_preprocessing.src.h5_constructor.CreateAstroObjectPKL import CreateAstroObjectPKL
# ----> 4 to_pkl = CreateAstroObjectPKL(chunks_dir='/home/magdalena/pipeline/data_preprocessing/data/test',
#       5                               output_dir='/home/magdalena/pipeline/data_preprocessing/data/test_pkl',
#       6                               n_jobs=1)
#
# File ~/pipeline/data_preprocessing/src/h5_constructor/CreateAstroObjectPKL.py:25, in CreateAstroObjectPKL.__init__(self, chunks_dir, output_dir, n_jobs)
#      22 def __init__(self, chunks_dir: str,output_dir:str,n_jobs:int = 1):
#      23
#      24     # List all chunk directories
# ---> 25     chunk_dirs = [d for d in os.listdir(chunks_dir) if d.startswith('chunk_')]
#      27     os.makedirs(output_dir, exist_ok=True)
#      28     print(chunk_dirs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/magdalena/pipeline/data_preprocessing/data/test'
