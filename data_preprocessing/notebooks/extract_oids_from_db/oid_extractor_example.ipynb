# %%
# %cd /home/magdalena/pipeline/data_preprocessing/
# Then use normal imports

from src.mining.OIDExtractor import OIDExtractor

import pandas as pd
# Out:
# /home/magdalena/pipeline/data_preprocessing

# %%
extractor = OIDExtractor(path_oids_to_pull='/home/magdalena/pipeline/data_preprocessing/data/OID_PARQUETS/2023_plussixdet_oids_.parquet',
                         path_to_save_dir='/home/magdalena/pipeline/data_preprocessing/data/test')
# Out:
# Pulling data by oid chunks of size 100:   4%|▍         | 9/207 [00:32<12:01,  3.64s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 extractor = OIDExtractor(path_oids_to_pull='/home/magdalena/pipeline/data_preprocessing/data/OID_PARQUETS/2023_plussixdet_oids_.parquet',
#       2                          path_to_save_dir='/home/magdalena/pipeline/data_preprocessing/data/test')
#
# File ~/pipeline/data_preprocessing/src/mining/OIDExtractor.py:52, in OIDExtractor.__init__(self, path_oids_to_pull, path_to_save_dir, chunk_size)
#      49 chunk_dir = os.path.join(data_folder_full_path, f"chunk_{i}")
#      50 os.makedirs(chunk_dir)
# ---> 52 self.process_chunk(chunk, chunk_dir, engine)
#
# File ~/pipeline/data_preprocessing/src/mining/OIDExtractor.py:100, in OIDExtractor.process_chunk(self, chunk, chunk_dir, engine)
#      95 # Query for PS1 data
# ...
