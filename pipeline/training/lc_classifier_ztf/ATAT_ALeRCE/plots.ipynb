# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
base_t = 0.2248
base_s = 0.4960
base_p = 0.6058

# %%
trans = [0.2207, 0.2288, 0.2279, 0.2383, 0.2228]
stoch = [0.4867, 0.4985, 0.4930 , 0.5085, 0.4863]
per = [0.6026, 0.6028, 0.5999, 0.6067, 0.6037]
augmentations = [
    "windows",
    "roll",
    "band permute",
    "5% random factor",
    "gauss time factor",
    #"gauss flux factor",
]


fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
plt.title("F1 Score per Superclass vs Augmentation Methods")
sns.heatmap(np.array([trans, stoch, per]), ax=ax, cmap="viridis", annot=True, fmt = '.4f')
ax.set_yticks(range(3), labels=["transient", "stochastic", "periodic"], rotation=-45)
ax.set_xticks(range(5), labels=augmentations, rotation=45)
