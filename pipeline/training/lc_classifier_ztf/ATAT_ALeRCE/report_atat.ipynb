# %%
import pandas as pd

from src.utils.data.AlerceDictionaries import ELASTICC_TAXONOMY, ZTF_TAXONOMY
from src.exploringtools.InitBackbone import InitBackbone
from src.exploringtools.InitClassifier import InitClassifier, ztf_order_classes
from src.exploringtools.InitDataloader import InitDataLoader

from src.exploringtools.InitCombinator import InitCombinator
from src.layers.classifiers.MultimodalClassifier import MultimodalClassifier
from src.layers.classifiers.HierClassifiery import Hier
from src.layers.transformer.ATAT import TabularTransformer, LightCurveTransformer
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
FP_DATASET = "/home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/data/datasets/ZTF_ff/final/LC_MD_FEAT_240627_windows_200_12/dataset.h5"
#FP_DATASET = "/home/mdelafuente/ORIGINAL/elasticc_dataset_update.h5"
FP_DATASET ='/home/mdelafuente/ZTF_SSL_Dataset/data/H5_files/BY_PARTITION/200_FF.h5'

DEVICE = 'cuda:0'
DATASET = 'test'
FP_DATASET ='/home/mdelafuente/ZTF_SSL_Dataset/data/H5_files/BY_PARTITION/200_FF.h5'
reports_1 = []
reports_2 = []

RANGE = 1

for i in range(RANGE):
    PATH = f'/home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/results/ZTF/LC_MD_FEAT/class_all_0/'


    test = InitCombinator(path_to_config_yaml=PATH,
                    lc_model= LightCurveTransformer,
                    tab_model= TabularTransformer,
                    classifier = MultimodalClassifier,
                    classifier_args={'use_lc':False,
                                     'use_tab':False,
                                     'use_mix':True},
                    arg_key='tab',
                    device = DEVICE)
    dl = InitDataLoader(update_dataset_path=FP_DATASET,update_batch_size=32,datamodule_args=test.args.datamodule)
    dl.init_test_dataset()


    val_preds, val_true =test.predict(dl.test_dataset, DEVICE) if DATASET == 'test' else test.predict(dl.validation_dataset, DEVICE)
    print(classification_report(val_true, np.argmax(val_preds, axis = -1), target_names=list(ZTF_TAXONOMY().keys()),digits = 4, output_dict=False))
    test.get_confusion_matrix(np.argmax(val_preds, axis = -1), val_true, dataset_type=DATASET, taxonomy = ZTF_TAXONOMY, plot_title= 'ZTF ATAT LC ONLY', order_classes=ztf_order_classes)
    reports_1.append(classification_report(val_true, np.argmax(val_preds, axis = -1), target_names=list(ZTF_TAXONOMY().keys()),digits = 4, output_dict=True))
# Out:
# False False True
# Found checkpoint 3072.ckpt
# Found checkpoint 3072.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 3072.ckpt
# Loaded backbone weights
# /home/mdelafuente/ZTF_SSL_Dataset/data/H5_files/BY_PARTITION/metadata/fold_0.joblib
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
#  23%|██▎       | 54/239 [00:01<00:03, 47.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 44
#      40 dl = InitDataLoader(update_dataset_path=FP_DATASET,update_batch_size=32,datamodule_args=test.args.datamodule)
#      41 dl.init_test_dataset()
# ---> 44 val_preds, val_true =test.predict(dl.test_dataset, DEVICE) if DATASET == 'test' else test.predict(dl.validation_dataset, DEVICE)
#      45 print(classification_report(val_true, np.argmax(val_preds, axis = -1), target_names=list(ZTF_TAXONOMY().keys()),digits = 4, output_dict=False))
#      46 test.get_confusion_matrix(np.argmax(val_preds, axis = -1), val_true, dataset_type=DATASET, taxonomy = ZTF_TAXONOMY, plot_title= 'ZTF ATAT LC ONLY', order_classes=ztf_order_classes)
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:98, in InitCombinator.predict(self, dataloader, device, pred_type)
#      96 b1 = {key: value.to(device=self.device) for key, value in b1.items()}
#      97 t = b1["labels"]
# ---> 98 emb = self.atat(**b1)
#      99 if pred_type == 'class':
#     101     emb = self.classifier(emb)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/layers/transformer/ATAT.py:232, in Combinator.forward(self, data, time, mask, tabular_feat, metadata_feat, extracted_feat, tab_mask, **kwargs)
#     220 def forward(
#     221     self,
#     222     data,
#    (...)
#     229     **kwargs
#     230 ):
# --> 232     lc_emb = self.transformer_lc(data, time, mask)
#     233     ft_emb = self.transformer_tab(tabular_feat, tab_mask)
#     234     # return torch.concat([lc_emb,ft_emb],axis  = -1)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/layers/transformer/ATAT.py:119, in LightCurveTransformer.forward(self, data, time, mask, metadata, features, **kwargs)
#     117 def forward(self, data, time, mask, metadata=None, features=None, **kwargs):
# --> 119     x_mod, m_mod, _ = self.embedding_light_curve(
#     120         x=data, t=time, mask=mask, metadata=metadata, features=features
#     121     )
#     122     x_emb = self.transformer_lc(
#     123         src=x_mod, src_key_padding_mask=~(m_mod.squeeze(-1))
#     124     )
#     125     return x_emb
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/layers/transformer/ATAT.py:97, in LightCurveTransformer.embedding_light_curve(self, x, t, mask, metadata, features, **kwargs)
#      95 def embedding_light_curve(self, x, t, mask, metadata=None, features=None, **kwargs):
# ---> 97     x_mod, m_mod, t_mod = self.time_encoder(
#      98         x, t, mask=mask, metadata=metadata, features=features
#      99     )
#     101     if self.sequence_norm:
#     102         x_mod = x_mod / (
#     103         torch.sqrt(torch.linalg.norm(x_mod, dim=(1), keepdim=True)) + 1e-8
#     104         )
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/layers/timeEncoders/TimeHandler.py:70, in TimeHandler.forward(self, x, t, mask, metadata, features)
#      66     x_band = self.time_encoders[i](
#      67         x[slices_x], t[slices_t], metadata=metadata, features=features
#      68     )
#      69 else:
# ---> 70     x_band = self.time_encoders[i](
#      71         x[slices_x], t[slices_t], metadata=metadata, features=features
#      72     )
#      74 t_band = t[slices_t]
#      75 m_band = mask[slices_m]
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/layers/timeEncoders/TimeFilmModified.py:144, in EarlyFusionEncoder.forward(self, x, t, metadata, features)
#     139 alpha, beta = self.timefilm_coeffs(t)
#     141 x_out = (
#     142     x_out * alpha + beta + vel + acc + stats + tabular
#     143 )
# --> 144 return self.dropout(x_out)
#
# File ~/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/module.py:1918, in Module.__getattr__(self, name)
#    1909         self._backward_pre_hooks = OrderedDict()
#    1911 # On the return type:
#    1912 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1913 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1916 # See full discussion on the problems with returning `Union` here
#    1917 # https://github.com/microsoft/pyright/issues/4213
# -> 1918 def __getattr__(self, name: str) -> Any:
#    1919     if "_parameters" in self.__dict__:
#    1920         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
reports_1
# Out:
# [{'AGN': {'precision': 0.8455284552845529,
#    'recall': 0.7482014388489209,
#    'f1-score': 0.7938931297709924,
#    'support': 556.0},
#   'QSO': {'precision': 0.8724202626641651,
#    'recall': 0.8157894736842105,
#    'f1-score': 0.843155031731641,
#    'support': 570.0},
#   'EA': {'precision': 0.8772893772893773,
#    'recall': 0.8403508771929824,
#    'f1-score': 0.8584229390681004,
#    'support': 570.0},
#   'YSO': {'precision': 0.7723735408560312,
#    'recall': 0.8151950718685832,
#    'f1-score': 0.7932067932067932,
#    'support': 487.0},
#   'SNIa': {'precision': 0.8648068669527897,
#    'recall': 0.8309278350515464,
#    'f1-score': 0.8475289169295478,
#    'support': 485.0},
#   'CV/Nova': {'precision': 0.8924050632911392,
#    'recall': 0.88125,
#    'f1-score': 0.8867924528301887,
#    'support': 320.0},
#   'RRLc': {'precision': 0.9195612431444241,
#    'recall': 0.870242214532872,
#    'f1-score': 0.8942222222222223,
#    'support': 578.0},
#   'RSCVn': {'precision': 0.7604166666666666,
#    'recall': 0.8220720720720721,
#    'f1-score': 0.79004329004329,
#    'support': 444.0},
#   'Blazar': {'precision': 0.6197916666666666,
#    'recall': 0.8814814814814815,
#    'f1-score': 0.72782874617737,
#    'support': 270.0},
#   'SNII': {'precision': 0.7671232876712328,
#    'recall': 0.6131386861313869,
#    'f1-score': 0.6815415821501014,
#    'support': 274.0},
#   'EB/EW': {'precision': 0.8239316239316239,
#    'recall': 0.8339100346020761,
#    'f1-score': 0.8288907996560619,
#    'support': 578.0},
#   'LPV': {'precision': 0.9253731343283582,
#    'recall': 0.9620689655172414,
#    'f1-score': 0.9433643279797126,
#    'support': 580.0},
#   'CEP': {'precision': 0.9049586776859504,
#    'recall': 0.773851590106007,
#    'f1-score': 0.8342857142857143,
#    'support': 566.0},
#   'RRLab': {'precision': 0.9209621993127147,
#    'recall': 0.9209621993127147,
#    'f1-score': 0.9209621993127147,
#    'support': 582.0},
#   'Periodic-Other': {'precision': 0.7028985507246377,
#    'recall': 0.8083333333333333,
#    'f1-score': 0.751937984496124,
#    'support': 240.0},
#   'DSCT': {'precision': 0.9026845637583892,
#    'recall': 0.8848684210526315,
#    'f1-score': 0.893687707641196,
#    'support': 304.0},
#   'SNIbc': {'precision': 0.36065573770491804,
#    'recall': 0.5116279069767442,
#    'f1-score': 0.4230769230769231,
#    'support': 86.0},
#   'SLSN': {'precision': 0.45454545454545453,
#    'recall': 0.5405405405405406,
#    'f1-score': 0.49382716049382713,
#    'support': 37.0},
#   'TDE': {'precision': 0.75,
#    'recall': 0.75,
#    'f1-score': 0.75,
#    'support': 16.0},
#   'SNIIb': {'precision': 0.043478260869565216,
#    'recall': 0.047619047619047616,
#    'f1-score': 0.045454545454545456,
#    'support': 21.0},
#   'SNIIn': {'precision': 0.21839080459770116,
#    'recall': 0.3584905660377358,
#    'f1-score': 0.2714285714285714,
#    'support': 53.0},
#   'Microlensing': {'precision': 1.0,
#    'recall': 1.0,
#    'f1-score': 1.0,
#    'support': 5.0},
#   'accuracy': 0.8257675150879035,
#   'macro avg': {'precision': 0.73634524717938,
#    'recall': 0.7504964434528241,
#    'f1-score': 0.7397068653616199,
#    'support': 7622.0},
#   'weighted avg': {'precision': 0.8366375897986962,
#    'recall': 0.8257675150879035,
#    'f1-score': 0.8287739737336259,
#    'support': 7622.0}}]

# %%
print(summarize_classification_reports(reports_1))
print('#####################')
# Out:
# \begin{table}[ht]
# \centering
# \small
# \begin{tabular}{lcccc}
# \toprule
#  &  &  &  &  \\
# \midrule
#          AGN  & 0.8145$\pm$nan &  0.8058$\pm$nan &  0.8101$\pm$nan &    556\\
#       Blazar  & 0.7003$\pm$nan &  0.7963$\pm$nan &  0.7452$\pm$nan &    270\\
#          CEP  & 0.8840$\pm$nan &  0.7809$\pm$nan &  0.8293$\pm$nan &    566\\
#      CV/Nova  & 0.8707$\pm$nan &  0.8625$\pm$nan &  0.8666$\pm$nan &    320\\
#         DSCT  & 0.7602$\pm$nan &  0.8553$\pm$nan &  0.8050$\pm$nan &    304\\
#           EA  & 0.8521$\pm$nan &  0.8491$\pm$nan &  0.8506$\pm$nan &    570\\
#        EB/EW  & 0.8295$\pm$nan &  0.8166$\pm$nan &  0.8230$\pm$nan &    578\\
#          LPV  & 0.9399$\pm$nan &  0.9431$\pm$nan &  0.9415$\pm$nan &    580\\
# Microlensing  & 0.2727$\pm$nan &  0.6000$\pm$nan &  0.3750$\pm$nan &      5\\
# Periodic-Other  & 0.6211$\pm$nan &  0.7375$\pm$nan &  0.6743$\pm$nan &    240\\
#          QSO  & 0.8419$\pm$nan &  0.8316$\pm$nan &  0.8367$\pm$nan &    570\\
#        RRLab  & 0.9220$\pm$nan &  0.8935$\pm$nan &  0.9075$\pm$nan &    582\\
#         RRLc  & 0.8973$\pm$nan &  0.8616$\pm$nan &  0.8791$\pm$nan &    578\\
#        RSCVn  & 0.7659$\pm$nan &  0.7883$\pm$nan &  0.7769$\pm$nan &    444\\
#         SLSN  & 0.4737$\pm$nan &  0.4865$\pm$nan &  0.4800$\pm$nan &     37\\
#         SNII  & 0.6813$\pm$nan &  0.6788$\pm$nan &  0.6801$\pm$nan &    274\\
#        SNIIb  & 0.1429$\pm$nan &  0.1429$\pm$nan &  0.1429$\pm$nan &     21\\
#        SNIIn  & 0.2340$\pm$nan &  0.2075$\pm$nan &  0.2200$\pm$nan &     53\\
#         SNIa  & 0.9007$\pm$nan &  0.7485$\pm$nan &  0.8176$\pm$nan &    485\\
#        SNIbc  & 0.2952$\pm$nan &  0.5698$\pm$nan &  0.3889$\pm$nan &     86\\
#          TDE  & 0.6667$\pm$nan &  0.7500$\pm$nan &  0.7059$\pm$nan &     16\\
#          YSO  & 0.7675$\pm$nan &  0.7659$\pm$nan &  0.7667$\pm$nan &    487\\
#     accuracy  0.8109$\pm$nan&
#    macro avg  & 0.6879$\pm$nan &  0.7169$\pm$nan &  0.6965$\pm$nan &   7622\\
# weighted avg  & 0.8205$\pm$nan &  0.8109$\pm$nan &  0.8141$\pm$nan &   7622\\
# \bottomrule
# \end{tabular}
# \caption{Classification Report}
# \label{tab:classification_report}
# \end{table}
# #####################

# %%
RANGE = 5
for i in range(RANGE):
    PATH = f'/home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/results/FINAL/LC_MD_FEAT/MM_class_v0000_MULTIMODAL_64128_0_{i}_moredropout_FROZEN/'
    #PATH = f'/home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/results/64_128/LC_MD_FEAT/MM_class_64_128_{i}/'
    test = InitCombinator(path_to_config_yaml=PATH,
                    lc_model= LightCurveTransformer,
                    tab_model= TabularTransformer,
                    classifier = MultimodalClassifier,
                    classifier_args={'use_lc':False,
                                     'use_tab':False,
                                     'use_mix':True},
                    arg_key='tab',
                    device = DEVICE)
    dl = InitDataLoader(update_dataset_path=FP_DATASET,update_batch_size=32,datamodule_args=test.args.datamodule)
    dl.init_test_dataset()
    val_preds, val_true =test.predict(dl.test_dataset, DEVICE) if DATASET == 'test' else test.predict(dl.validation_dataset, DEVICE)
    #print(classification_report(val_true, np.argmax(val_preds, axis = -1), target_names=list(ZTF_TAXONOMY().keys()),digits = 4, output_dict=False))
    #test.get_confusion_matrix(np.argmax(val_preds, axis = -1), val_true, dataset_type=DATASET, taxonomy = ZTF_TAXONOMY, plot_title= 'ZTF ATAT LC ONLY', order_classes=ztf_order_classes)
    reports_2.append(classification_report(val_true, np.argmax(val_preds, axis = -1), target_names=list(ZTF_TAXONOMY().keys()),digits = 4, output_dict=True))

def summarize_classification_reports(reports):
    """
    Given a list of sklearn classification_report dictionaries (with output_dict=True),
    compute the mean and standard deviation across them and return a formatted string report.
    """
    # Convert each report to a DataFrame and collect them
    df_list = [pd.DataFrame(r).transpose() for r in reports]

    # Align all DataFrames, using outer join to include all possible labels
    all_labels = sorted(set().union(*[df.index for df in df_list]))
    df_list = [df.reindex(all_labels) for df in df_list]

    # Combine and group by label
    combined = pd.concat(df_list).groupby(level=0)

    # Compute mean and std
    mean_df = combined.mean()
    std_df = combined.std()

    # Format the output string
    report_str = ""
    metrics = ['precision', 'recall', 'f1-score']

    for label in mean_df.index:
        if label == 'accuracy':
            # Accuracy is a single float, stored in the "precision" column
            acc_mean = mean_df.loc[label].get('precision', float('nan'))
            acc_std = std_df.loc[label].get('precision', float('nan'))
            report_str += f"{label:>12}  {acc_mean:.4f}$\\pm${acc_std:.4f}&\n"
        else:
            values = []
            for metric in metrics:
                mean_val = mean_df.loc[label].get(metric, float('nan'))
                std_val = std_df.loc[label].get(metric, float('nan'))
                values.append(f"{mean_val:.4f}$\\pm${std_val:.4f} &")
            support = mean_df.loc[label].get('support', float('nan'))
            report_str += f"{label:>12}  & " + "  ".join(values) + f"  {int(support):>5}" +'\\\ ' + '\n'
        top = [
        r'\begin{table}[ht]',
        r'\centering',
        r'\small',
        r'\begin{tabular}{lcccc}',
        r'\toprule',
        '{} {} '.format(4*' & ',r'\\'),
        r'\midrule'
        '\n'
    ]
    bottom= [
        r'\bottomrule',
        r'\end{tabular}',
        r'\caption{Classification Report}',
        r'\label{tab:classification_report}',
        r'\end{table}'
    ]
    return '\n'.join(top) +  report_str+ '\n'.join(bottom)


##########


print(summarize_classification_reports(reports_1))
print('#####################')
print(summarize_classification_reports(reports_2))
# Out:
# <>:57: SyntaxWarning: invalid escape sequence '\ '
# <>:57: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_3655004/2686703368.py:57: SyntaxWarning: invalid escape sequence '\ '
#   report_str += f"{label:>12}  & " + "  ".join(values) + f"  {int(support):>5}" +'\\\ ' + '\n'
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# False False True
# Found checkpoint 5664.ckpt
# Found checkpoint 5664.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 5664.ckpt
# Loaded backbone weights
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
# 100%|██████████| 239/239 [00:03<00:00, 62.46it/s]
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# False False True
# Found checkpoint 10080.ckpt
# Found checkpoint 10080.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 10080.ckpt
# Loaded backbone weights
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
# 100%|██████████| 239/239 [00:03<00:00, 62.44it/s]
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# False False True
# Found checkpoint 5664.ckpt
# Found checkpoint 5664.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 5664.ckpt
# Loaded backbone weights
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
# 100%|██████████| 239/239 [00:03<00:00, 63.72it/s]
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# False False True
# Found checkpoint 7392.ckpt
# Found checkpoint 7392.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 7392.ckpt
# Loaded backbone weights
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
# 100%|██████████| 239/239 [00:03<00:00, 62.83it/s]
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /home/mdelafuente/pipeline/pipeline/training/lc_classifier_ztf/ATAT_ALeRCE/src/exploringtools/InitCombinator.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_clip = load(
# False False True
# Found checkpoint 5856.ckpt
# Found checkpoint 5856.ckpt
# Loaded backbone weights
# Loaded backbone weights
# Found checkpoint 5856.ckpt
# Loaded backbone weights
# /home/mdelafuente/miniconda3/envs/ATAT/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2888: RuntimeWarning: invalid value encountered in subtract
#   np.interp(X_col_finite, quantiles, self.references_)
# device set to cuda:0
# 100%|██████████| 239/239 [00:03<00:00, 64.81it/s]
# \begin{table}[ht]
# \centering
# \small
# \begin{tabular}{lcccc}
# \toprule
#  &  &  &  &  \\
# \midrule
#          AGN  & 0.3077$\pm$0.0521 &  0.2252$\pm$0.1122 &  0.2491$\pm$0.0916 &    556\\
#       Blazar  & 0.1741$\pm$0.0374 &  0.1556$\pm$0.0639 &  0.1587$\pm$0.0453 &    270\\
#          CEP  & 0.5110$\pm$0.0472 &  0.1852$\pm$0.0431 &  0.2698$\pm$0.0503 &    566\\
#      CV/Nova  & 0.3071$\pm$0.1297 &  0.1906$\pm$0.0500 &  0.2288$\pm$0.0725 &    320\\
#         DSCT  & 0.2272$\pm$0.0425 &  0.4125$\pm$0.0572 &  0.2882$\pm$0.0283 &    304\\
#           EA  & 0.5345$\pm$0.0713 &  0.3688$\pm$0.1193 &  0.4251$\pm$0.0787 &    570\\
#        EB/EW  & 0.4384$\pm$0.0476 &  0.3910$\pm$0.0891 &  0.4073$\pm$0.0465 &    578\\
#          LPV  & 0.6021$\pm$0.0809 &  0.4972$\pm$0.1835 &  0.5173$\pm$0.1138 &    580\\
# Microlensing  & 0.0075$\pm$0.0018 &  0.5200$\pm$0.1789 &  0.0148$\pm$0.0035 &      5\\
# Periodic-Other  & 0.1459$\pm$0.0362 &  0.2775$\pm$0.0590 &  0.1840$\pm$0.0243 &    240\\
#          QSO  & 0.4346$\pm$0.0790 &  0.4077$\pm$0.1634 &  0.3971$\pm$0.0976 &    570\\
#        RRLab  & 0.5634$\pm$0.0910 &  0.4354$\pm$0.0822 &  0.4807$\pm$0.0335 &    582\\
#         RRLc  & 0.4839$\pm$0.0580 &  0.2211$\pm$0.0839 &  0.2929$\pm$0.0738 &    578\\
#        RSCVn  & 0.2604$\pm$0.0457 &  0.1739$\pm$0.0675 &  0.2027$\pm$0.0536 &    444\\
#         SLSN  & 0.0601$\pm$0.0258 &  0.3405$\pm$0.1450 &  0.0988$\pm$0.0392 &     37\\
#         SNII  & 0.1975$\pm$0.0590 &  0.0292$\pm$0.0220 &  0.0496$\pm$0.0351 &    274\\
#        SNIIb  & 0.0080$\pm$0.0065 &  0.0952$\pm$0.0673 &  0.0143$\pm$0.0109 &     21\\
#        SNIIn  & 0.0060$\pm$0.0134 &  0.0264$\pm$0.0591 &  0.0098$\pm$0.0218 &     53\\
#         SNIa  & 0.3882$\pm$0.0871 &  0.2928$\pm$0.2219 &  0.3040$\pm$0.1666 &    485\\
#        SNIbc  & 0.0922$\pm$0.0355 &  0.1442$\pm$0.1077 &  0.0954$\pm$0.0393 &     86\\
#          TDE  & 0.0178$\pm$0.0054 &  0.6125$\pm$0.1492 &  0.0344$\pm$0.0100 &     16\\
#          YSO  & 0.2793$\pm$0.0619 &  0.1314$\pm$0.0776 &  0.1586$\pm$0.0589 &    487\\
#     accuracy  0.2880$\pm$0.0485&
#    macro avg  & 0.2749$\pm$0.0054 &  0.2788$\pm$0.0231 &  0.2219$\pm$0.0266 &   7622\\
# weighted avg  & 0.3906$\pm$0.0081 &  0.2880$\pm$0.0485 &  0.3062$\pm$0.0352 &   7622\\
# \bottomrule
# \end{tabular}
# \caption{Classification Report}
# \label{tab:classification_report}
# \end{table}
# #####################
# \begin{table}[ht]
# \centering
# \small
# \begin{tabular}{lcccc}
# \toprule
#  &  &  &  &  \\
# \midrule
#          AGN  & 0.5228$\pm$0.0108 &  0.3209$\pm$0.0175 &  0.3974$\pm$0.0133 &    556\\
#       Blazar  & 0.3977$\pm$0.0080 &  0.4963$\pm$0.0283 &  0.4411$\pm$0.0101 &    270\\
#          CEP  & 0.6242$\pm$0.0108 &  0.5495$\pm$0.0233 &  0.5843$\pm$0.0156 &    566\\
#      CV/Nova  & 0.5391$\pm$0.0173 &  0.5994$\pm$0.0313 &  0.5670$\pm$0.0100 &    320\\
#         DSCT  & 0.5727$\pm$0.0323 &  0.7362$\pm$0.0367 &  0.6429$\pm$0.0103 &    304\\
#           EA  & 0.6549$\pm$0.0370 &  0.4940$\pm$0.0171 &  0.5624$\pm$0.0094 &    570\\
#        EB/EW  & 0.6348$\pm$0.0368 &  0.6381$\pm$0.0246 &  0.6353$\pm$0.0088 &    578\\
#          LPV  & 0.8059$\pm$0.0257 &  0.8603$\pm$0.0180 &  0.8318$\pm$0.0062 &    580\\
# Microlensing  & 0.0076$\pm$0.0106 &  0.0800$\pm$0.1095 &  0.0139$\pm$0.0193 &      5\\
# Periodic-Other  & 0.2757$\pm$0.0088 &  0.3458$\pm$0.0265 &  0.3067$\pm$0.0148 &    240\\
#          QSO  & 0.6028$\pm$0.0115 &  0.6491$\pm$0.0194 &  0.6248$\pm$0.0040 &    570\\
#        RRLab  & 0.8009$\pm$0.0270 &  0.7897$\pm$0.0130 &  0.7949$\pm$0.0074 &    582\\
#         RRLc  & 0.7841$\pm$0.0172 &  0.7149$\pm$0.0248 &  0.7475$\pm$0.0092 &    578\\
#        RSCVn  & 0.4509$\pm$0.0078 &  0.5297$\pm$0.0202 &  0.4869$\pm$0.0046 &    444\\
#         SLSN  & 0.1465$\pm$0.0271 &  0.4919$\pm$0.0401 &  0.2236$\pm$0.0254 &     37\\
#         SNII  & 0.4694$\pm$0.0497 &  0.1533$\pm$0.0693 &  0.2266$\pm$0.0824 &    274\\
#        SNIIb  & 0.0224$\pm$0.0065 &  0.1333$\pm$0.0398 &  0.0381$\pm$0.0109 &     21\\
#        SNIIn  & 0.0686$\pm$0.0128 &  0.1509$\pm$0.0517 &  0.0937$\pm$0.0226 &     53\\
#         SNIa  & 0.6737$\pm$0.0228 &  0.4718$\pm$0.0479 &  0.5536$\pm$0.0327 &    485\\
#        SNIbc  & 0.2075$\pm$0.0347 &  0.2977$\pm$0.0469 &  0.2423$\pm$0.0306 &     86\\
#          TDE  & 0.0865$\pm$0.0145 &  0.5125$\pm$0.0815 &  0.1478$\pm$0.0236 &     16\\
#          YSO  & 0.4831$\pm$0.0151 &  0.4452$\pm$0.0214 &  0.4631$\pm$0.0145 &    487\\
#     accuracy  0.5642$\pm$0.0069&
#    macro avg  & 0.4469$\pm$0.0061 &  0.4755$\pm$0.0049 &  0.4375$\pm$0.0081 &   7622\\
# weighted avg  & 0.5975$\pm$0.0075 &  0.5642$\pm$0.0069 &  0.5710$\pm$0.0080 &   7622\\
# \bottomrule
# \end{tabular}
# \caption{Classification Report}
# \label{tab:classification_report}
# \end{table}

# %%
from pprint import pprint
#pprint(reports_1[0])
import pandas as pd
metrics =[]

for rep in reports_1:

  metrics.append(pd.DataFrame(rep))


mean_stats_1 = pd.concat(metrics).reset_index().rename(columns = {'index':'metric'}).groupby('metric').describe()#.sort_values('level_1')#columns#.query('level_1 == std')
mean_stats_1 = mean_stats_1.T.reset_index().query('level_1 == "mean"')

for rep in reports_2:

  metrics.append(pd.DataFrame(rep))

mean_stats_2 = pd.concat(metrics).reset_index().rename(columns = {'index':'metric'}).groupby('metric').describe()#.sort_values('level_1')#columns#.query('level_1 == std')
mean_stats_2 = mean_stats_2.T.reset_index().query('level_1 == "mean"')

# %%
mean_collected = mean_stats_1.merge(mean_stats_2, on = ['level_0','level_1','support'],suffixes = ['_baseline','_pretrained'], how = 'left').drop(columns = 'level_1')
mean_collected = mean_collected[['level_0', 'precision_baseline', 'recall_baseline', 'f1-score_baseline',
        'precision_pretrained',
       'recall_pretrained','f1-score_pretrained', 'support']]
mean_collected['support'] =mean_collected['support'].astype(int)
mean_collected = mean_collected.round(4).rename(columns = {'level_0':'class'})#.drop(columns = 'metric')

# %%
from pprint import pprint
#pprint(reports_1[0])
import pandas as pd
metrics =[]

for rep in reports_1:

  metrics.append(pd.DataFrame(rep))


std_stats_1 = pd.concat(metrics).reset_index().rename(columns = {'index':'metric'}).groupby('metric').describe()#.sort_values('level_1')#columns#.query('level_1 == std')
std_stats_1 = std_stats_1.T.reset_index().query('level_1 == "std"')

for rep in reports_2:

  metrics.append(pd.DataFrame(rep))

std_stats_2 = pd.concat(metrics).reset_index().rename(columns = {'index':'metric'}).groupby('metric').describe()#.sort_values('level_1')#columns#.query('level_1 == std')
std_stats_2 = std_stats_2.T.reset_index().query('level_1 == "std"')

# %%
std_collected = std_stats_1.merge(std_stats_2, on = ['level_0','level_1','support'],suffixes = ['_baseline','_pretrained'], how = 'left').drop(columns = 'level_1')
std_collected = std_collected[['level_0', 'precision_baseline', 'recall_baseline', 'f1-score_baseline',
        'precision_pretrained',
       'recall_pretrained','f1-score_pretrained', 'support']]
std_collected['support'] =std_collected['support'].astype(int)
std_collected = std_collected.round(4).rename(columns = {'level_0':'class'})#.drop(columns = 'metric')

# %%
COLS = ['precision_baseline','recall_baseline','f1-score_baseline','precision_pretrained','recall_pretrained','f1-score_pretrained']
formated = pd.concat([mean_collected['class'],"&"+mean_collected[COLS].astype(str) + "\pm" + std_collected[COLS].astype(str),"&" + mean_collected['support'].astype(str) + f'\ \\'], axis = 1)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_3655004/3413213311.py:2: SyntaxWarning: invalid escape sequence '\p'
#   formated = pd.concat([mean_collected['class'],"&"+mean_collected[COLS].astype(str) + "\pm" + std_collected[COLS].astype(str),"&" + mean_collected['support'].astype(str) + f'\ \\'], axis = 1)
# /tmp/ipykernel_3655004/3413213311.py:2: SyntaxWarning: invalid escape sequence '\ '
#   formated = pd.concat([mean_collected['class'],"&"+mean_collected[COLS].astype(str) + "\pm" + std_collected[COLS].astype(str),"&" + mean_collected['support'].astype(str) + f'\ \\'], axis = 1)

# %%
formated = pd.concat([mean_collected['class'],mean_collected[COLS].astype(str) + "\pm" + std_collected[COLS].astype(str),mean_collected['support'].astype(str)], axis = 1)
print(formated.to_latex())
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# \begin{tabular}{lllllllll}
# \toprule
#  & class & precision_baseline & recall_baseline & f1-score_baseline & precision_pretrained & recall_pretrained & f1-score_pretrained & support \\
# \midrule
# 0 & AGN & 0.3077\pm0.0521 & 0.2252\pm0.1122 & 0.2491\pm0.0916 & 0.4153\pm0.1188 & 0.273\pm0.091 & 0.3232\pm0.0996 & 556 \\
# 1 & QSO & 0.4346\pm0.079 & 0.4077\pm0.1634 & 0.3971\pm0.0976 & 0.5187\pm0.1034 & 0.5284\pm0.168 & 0.511\pm0.1365 & 570 \\
# 2 & EA & 0.5345\pm0.0713 & 0.3688\pm0.1193 & 0.4251\pm0.0787 & 0.5947\pm0.083 & 0.4314\pm0.104 & 0.4938\pm0.0896 & 570 \\
# 3 & YSO & 0.2793\pm0.0619 & 0.1314\pm0.0776 & 0.1586\pm0.0589 & 0.3812\pm0.1155 & 0.2883\pm0.1739 & 0.3109\pm0.1655 & 487 \\
# 4 & SNIa & 0.3882\pm0.0871 & 0.2928\pm0.2219 & 0.304\pm0.1666 & 0.531\pm0.162 & 0.3823\pm0.1783 & 0.4288\pm0.1736 & 485 \\
# 5 & CV/Nova & 0.3071\pm0.1297 & 0.1906\pm0.05 & 0.2288\pm0.0725 & 0.4231\pm0.1502 & 0.395\pm0.219 & 0.3979\pm0.1848 & 320 \\
# 6 & RRLc & 0.4839\pm0.058 & 0.2211\pm0.0839 & 0.2929\pm0.0738 & 0.634\pm0.1633 & 0.468\pm0.2667 & 0.5202\pm0.2447 & 578 \\
# 7 & RSCVn & 0.2604\pm0.0457 & 0.1739\pm0.0675 & 0.2027\pm0.0536 & 0.3557\pm0.105 & 0.3518\pm0.1933 & 0.3448\pm0.154 & 444 \\
# 8 & Blazar & 0.1741\pm0.0374 & 0.1556\pm0.0639 & 0.1587\pm0.0453 & 0.2859\pm0.1205 & 0.3259\pm0.1855 & 0.2999\pm0.152 & 270 \\
# 9 & SNII & 0.1975\pm0.059 & 0.0292\pm0.022 & 0.0496\pm0.0351 & 0.3334\pm0.1523 & 0.0912\pm0.0814 & 0.1381\pm0.1107 & 274 \\
# 10 & EB/EW & 0.4384\pm0.0476 & 0.391\pm0.0891 & 0.4073\pm0.0465 & 0.5366\pm0.111 & 0.5145\pm0.144 & 0.5213\pm0.1242 & 578 \\
# 11 & LPV & 0.6021\pm0.0809 & 0.4972\pm0.1835 & 0.5173\pm0.1138 & 0.704\pm0.1214 & 0.6788\pm0.2275 & 0.6745\pm0.1823 & 580 \\
# 12 & CEP & 0.511\pm0.0472 & 0.1852\pm0.0431 & 0.2698\pm0.0503 & 0.5676\pm0.0678 & 0.3673\pm0.1948 & 0.4271\pm0.1694 & 566 \\
# 13 & RRLab & 0.5634\pm0.091 & 0.4354\pm0.0822 & 0.4807\pm0.0335 & 0.6821\pm0.1403 & 0.6125\pm0.1948 & 0.6378\pm0.1671 & 582 \\
# 14 & Periodic-Other & 0.1459\pm0.0362 & 0.2775\pm0.059 & 0.184\pm0.0243 & 0.2108\pm0.0728 & 0.3117\pm0.0562 & 0.2453\pm0.0674 & 240 \\
# 15 & DSCT & 0.2272\pm0.0425 & 0.4125\pm0.0572 & 0.2882\pm0.0283 & 0.4\pm0.1855 & 0.5743\pm0.1765 & 0.4655\pm0.188 & 304 \\
# 16 & SNIbc & 0.0922\pm0.0355 & 0.1442\pm0.1077 & 0.0954\pm0.0393 & 0.1498\pm0.0692 & 0.2209\pm0.1126 & 0.1689\pm0.0843 & 86 \\
# 17 & SLSN & 0.0601\pm0.0258 & 0.3405\pm0.145 & 0.0988\pm0.0392 & 0.1033\pm0.0519 & 0.4162\pm0.1282 & 0.1612\pm0.0728 & 37 \\
# 18 & TDE & 0.0178\pm0.0054 & 0.6125\pm0.1492 & 0.0344\pm0.01 & 0.0522\pm0.0377 & 0.5625\pm0.125 & 0.0911\pm0.0621 & 16 \\
# 19 & SNIIb & 0.008\pm0.0065 & 0.0952\pm0.0673 & 0.0143\pm0.0109 & 0.0152\pm0.0098 & 0.1143\pm0.0559 & 0.0262\pm0.0162 & 21 \\
# 20 & SNIIn & 0.006\pm0.0134 & 0.0264\pm0.0591 & 0.0098\pm0.0218 & 0.0373\pm0.0352 & 0.0887\pm0.0839 & 0.0517\pm0.049 & 53 \\
# 21 & Microlensing & 0.0075\pm0.0018 & 0.52\pm0.1789 & 0.0148\pm0.0035 & 0.0076\pm0.0072 & 0.3\pm0.2708 & 0.0143\pm0.0131 & 5 \\
# 22 & accuracy & 0.288\pm0.0485 & 0.288\pm0.0485 & 0.288\pm0.0485 & nan\pmnan & nan\pmnan & nan\pmnan & 0 \\
# 23 & macro avg & 0.2749\pm0.0054 & 0.2788\pm0.0231 & 0.2219\pm0.0266 & 0.3609\pm0.0908 & 0.3771\pm0.1048 & 0.3297\pm0.1152 & 7622 \\
# 24 & weighted avg & 0.3906\pm0.0081 & 0.288\pm0.0485 & 0.3062\pm0.0352 & 0.4941\pm0.1093 & 0.4261\pm0.1492 & 0.4386\pm0.1416 & 7622 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_3655004/848190151.py:1: SyntaxWarning: invalid escape sequence '\p'
#   formated = pd.concat([mean_collected['class'],mean_collected[COLS].astype(str) + "\pm" + std_collected[COLS].astype(str),mean_collected['support'].astype(str)], axis = 1)
